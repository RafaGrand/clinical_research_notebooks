# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import urllib
import pandas as pd
import sys
from sqlalchemy import create_engine, MetaData, Table, select, engine
pd.set_option('display.max_rows',None)

server = '#yourserver' 
database = '#yourdbname' 
username = '#yourusername' 
password = '#yourpassword' 
params = urllib.parse.quote_plus('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)

engine = create_engine("mssql+pyodbc:///?odbc_connect=%s" % params)

df = pd.read_sql_query("select * from #yourtable", engine)
#df.query('Diagnostico.str.contains("COVID")', engine='python')
df
df.dtypes
df.to_excel (r'#yourpath\#filename.xlsx', index = False, header=True)
df.to_csv (r'#yourpath\#filename.csv', index = False, header=True)
# Out:
#                           Pabellon   Cama           Cedula Tipo  \
# 0   HOSPITALIZACION PISO 4          H401A  2213795          CC
# 1   HOSPITALIZACION PISO 4          H401B  14137495         CC
# 2   HOSPITALIZACION PISO 4          H402A  1005838779       CC
# 3   HOSPITALIZACION PISO 4          H402B  93387298         CC
# 4   HOSPITALIZACION PISO 4          H403A  93374883         CC
# 5   HOSPITALIZACION PISO 4          H403B  93389429         CC
# 6   HOSPITALIZACION PISO 4          H404A  1796219          CC
# 7   HOSPITALIZACION PISO 4          H405A  28513117         CC
# 8   HOSPITALIZACION PISO 4          H405B  20616200         CC
# 9   HOSPITALIZACION PISO 4          H406A  14235032         CC
# 10  HOSPITALIZACION PISO 4          H407A  28961218         CC
# 11  HOSPITALIZACION PISO 4          H407B  32411716         CC
# 12  HOSPITALIZACION PISO 4          H408A  28930267         CC
# 13  HOSPITALIZACION PISO 4          H408B  30208914         CC
# ...
